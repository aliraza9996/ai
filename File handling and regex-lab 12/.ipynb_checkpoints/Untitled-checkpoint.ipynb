# %%
# task1, Reading a file
fo = open("task1.txt", "r+")
content =  fo.read()
print(content)
fo.close()
# Out:
# Maira Babar
# 01-131172-011

# %%
# Task 2, Open a file
fo = open("task2.txt", "w")
fo.write( "My name is Maira Babar")
fo.close()

# %%
# Read a file
fo = open("DataSet.csv", "r+")
content =  fo.read()
print(content)
fo.close()
# Out:
# "","group","wl1","wl2","wl3","se1","se2","se3"
# "1","Control",4,3,3,14,13,15
# "2","Control",4,4,3,13,14,17
# "3","Control",4,3,1,17,12,16
# "4","Control",3,2,1,11,11,12
# "5","Control",5,3,2,16,15,14
# "6","Control",6,5,4,17,18,18
# "7","Control",6,5,4,17,16,19
# "8","Control",5,4,1,13,15,15
# "9","Control",5,4,1,14,14,15
# "10","Control",3,3,2,14,15,13
# "11","Control",4,2,2,16,16,11
# "12","Control",5,2,1,15,13,16
# "13","Diet",6,3,2,12,11,14
# "14","Diet",5,4,1,13,14,15
# "15","Diet",7,6,3,17,11,18
# "16","Diet",6,4,2,16,15,18
# "17","Diet",3,2,1,16,17,15
# "18","Diet",5,5,4,13,11,18
# "19","Diet",4,3,1,12,11,14
# "20","Diet",4,2,1,12,11,11
# "21","Diet",6,5,3,17,16,19
# "22","Diet",7,6,4,19,19,19
# "23","Diet",4,3,2,15,15,15
# "24","Diet",7,4,3,16,14,18
# "25","DietEx",7,7,4,15,11,19
# "26","DietEx",4,7,1,16,12,18
# "27","DietEx",9,7,3,13,12,17
# "28","DietEx",3,4,1,16,13,17
# "29","DietEx",3,5,1,13,13,16
# "30","DietEx",6,5,2,15,12,18
# "31","DietEx",6,6,3,15,13,18
# ...

# %%
import pandas as pd
pd.read_csv("DataSet.csv")
# Out:
#     Unnamed: 0    group  wl1  wl2  wl3  se1  se2  se3
# 0            1  Control    4    3    3   14   13   15
# 1            2  Control    4    4    3   13   14   17
# 2            3  Control    4    3    1   17   12   16
# 3            4  Control    3    2    1   11   11   12
# 4            5  Control    5    3    2   16   15   14
# 5            6  Control    6    5    4   17   18   18
# 6            7  Control    6    5    4   17   16   19
# 7            8  Control    5    4    1   13   15   15
# 8            9  Control    5    4    1   14   14   15
# 9           10  Control    3    3    2   14   15   13
# 10          11  Control    4    2    2   16   16   11
# 11          12  Control    5    2    1   15   13   16
# 12          13     Diet    6    3    2   12   11   14
# 13          14     Diet    5    4    1   13   14   15
# 14          15     Diet    7    6    3   17   11   18
# 15          16     Diet    6    4    2   16   15   18
# ...
